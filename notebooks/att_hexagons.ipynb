# %% [markdown]
# ## AT&T 5G Coverage
# This notebook extracts geopackages from the FCC's Broadband Data Collection portal consisting of level 9 h3 hexagons using their public API. Rather than storing that enormous amount of data we extract the attribute table and later use the h3 library to recreate only what we need.
#
# While functional these notebooks were built in pieces and need to be cleaned up.

# %%
import requests
import json
import os
from dotenv import load_dotenv

def list_availability_data(date, username, hash_value, verify_ssl=True):
    """
    List FCC availability data for a specific date.
    
    Parameters:
    -----------
    date : str
        Date in format 'YYYY-MM-DD' (e.g., '2024-06-30')
    username : str
        FCC API username
    hash_value : str
        FCC API hash value
    verify_ssl : bool
        Whether to verify SSL certificates (default True)
    
    Returns:
    --------
    dict : API response data
    """
    
    url = f'https://bdc.fcc.gov/api/public/map/downloads/listAvailabilityData/{date}'
    
    headers = {
        'username': username,
        'hash_value': hash_value,
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36',
        'Accept': 'application/json',
        'Connection': 'close'  # Don't keep connection alive
    }
    
    # Check that we're passing the correct variables
    print(f"Requesting availability data for {date}...")
    print(f"URL: {url}")
    print(f"Username: {username[:3]}***")
    
    # Create session with retry logic
    session = requests.Session()
    adapter = requests.adapters.HTTPAdapter(
        max_retries=requests.adapters.Retry(
            total=3,
            backoff_factor=1,
            status_forcelist=[500, 502, 503, 504]
        )
    )
    session.mount('https://', adapter)
    session.mount('http://', adapter)
    
    try:
        response = session.get(
            url, 
            headers=headers, 
            timeout=(10, 30),  # (connect, read) timeout
            verify=verify_ssl
        )
        
        # Should probably only print this verification once
        print(f"Status Code: {response.status_code}")
        print(f"Response Headers: {dict(response.headers)}")
        
        response.raise_for_status()
        
        data = response.json()
        
        print(f"\nSuccess! Retrieved data:")
        print(json.dumps(data, indent=2))
        
        return data
        
    except requests.exceptions.HTTPError as e:
        print(f"\nHTTP Error: {e}")
        print(f"Status Code: {response.status_code}")
        print(f"Response: {response.text}")
        raise
    except requests.exceptions.ConnectionError as e:
        print(f"\nConnection Error: {e}")
        print("\nTroubleshooting tips:")
        print("1. Verify your username and hash_value are correct")
        print("2. Check if you need to register/activate API access with FCC")
        print("3. Try accessing the URL in a browser first")
        print("4. Check if there's a firewall blocking the connection")
        print("5. Try with verify_ssl=False if SSL is the issue")
        raise
    except requests.exceptions.RequestException as e:
        print(f"\nRequest Error: {e}")
        raise
    except json.JSONDecodeError as e:
        print(f"\nJSON Decode Error: {e}")
        print(f"Response text: {response.text}")
        raise
    finally:
        session.close()


if __name__ == "__main__":
    # Configuration
    DATE = "2025-06-30"
    USERNAME   = os.environ["FCC_USERNAME"]
    HASH_VALUE = os.environ["FCC_HASH_VALUE"]
    # Get the list
    result = list_availability_data(
        date=DATE,
        username=USERNAME,
        hash_value=HASH_VALUE
    )

# %%
# Filter records with category='Provider' and subcategory='Hexagon Coverage'
# Combine this with the above cell to prevent "result" from clearing

filtered_records = [
    record for record in result['data']
    if record.get('category') == 'Provider' 
    and record.get('subcategory') == 'Hexagon Coverage'
]

print(f"Found {len(filtered_records)} records")
filtered_records
# Out:
# Found 1189 records
# [{'file_id': 1442447,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '300',
#   'technology_code_desc': '3G',
#   'speed_tier': None,
#   'state_fips': '60',
#   'state_name': 'American Samoa',
#   'provider_id': '170012',
#   'provider_name': 'American Samoa Telecom, LLC',
#   'file_type': 'gis',
#   'file_name': 'bdc_60_170012_3G_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '1072'},
#  {'file_id': 1442444,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '300',
#   'technology_code_desc': '3G',
#   'speed_tier': None,
#   'state_fips': '72',
#   'state_name': 'Puerto Rico',
#   'provider_id': '170001',
#   'provider_name': 'Puerto Rico Telephone Company, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_72_170001_3G_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '71486'},
#  {'file_id': 1442294,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '300',
#   'technology_code_desc': '3G',
#   'speed_tier': None,
#   'state_fips': '46',
#   'state_name': 'South Dakota',
#   'provider_id': '130886',
#   'provider_name': 'NE Colorado Cellular, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_46_130886_3G_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '23651'},
#  {'file_id': 1442450,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '300',
#   'technology_code_desc': '3G',
#   'speed_tier': None,
#   'state_fips': '66',
#   'state_name': 'Guam',
#   'provider_id': '220001',
#   'provider_name': 'PTI Pacifica Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_66_220001_3G_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '3646'},
#  {'file_id': 1442468,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '300',
#   'technology_code_desc': '3G',
#   'speed_tier': None,
#   'state_fips': '31',
#   'state_name': 'Nebraska',
#   'provider_id': '360114',
#   'provider_name': 'Union Holding Corp.',
#   'file_type': 'gis',
#   'file_name': 'bdc_31_360114_3G_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '5'},
#  {'file_id': 1442331,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '300',
#   'technology_code_desc': '3G',
#   'speed_tier': None,
#   'state_fips': '04',
#   'state_name': 'Arizona',
#   'provider_id': '131208',
#   'provider_name': 'Smith Bagley, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_04_131208_3G_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '78638'},
#  {'file_id': 1442332,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '300',
#   'technology_code_desc': '3G',
#   'speed_tier': None,
#   'state_fips': '08',
#   'state_name': 'Colorado',
#   'provider_id': '131208',
#   'provider_name': 'Smith Bagley, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_08_131208_3G_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '78'},
#  {'file_id': 1442465,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '300',
#   'technology_code_desc': '3G',
#   'speed_tier': None,
#   'state_fips': '46',
#   'state_name': 'South Dakota',
#   'provider_id': '360114',
#   'provider_name': 'Union Holding Corp.',
#   'file_type': 'gis',
#   'file_name': 'bdc_46_360114_3G_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '3'},
#  {'file_id': 1442291,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '300',
#   'technology_code_desc': '3G',
#   'speed_tier': None,
#   'state_fips': '31',
#   'state_name': 'Nebraska',
#   'provider_id': '130886',
#   'provider_name': 'NE Colorado Cellular, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_31_130886_3G_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '756417'},
#  {'file_id': 1442295,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '300',
#   'technology_code_desc': '3G',
#   'speed_tier': None,
#   'state_fips': '08',
#   'state_name': 'Colorado',
#   'provider_id': '130886',
#   'provider_name': 'NE Colorado Cellular, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_08_130886_3G_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '613841'},
#  {'file_id': 1442466,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '300',
#   'technology_code_desc': '3G',
#   'speed_tier': None,
#   'state_fips': '56',
#   'state_name': 'Wyoming',
#   'provider_id': '360114',
#   'provider_name': 'Union Holding Corp.',
#   'file_type': 'gis',
#   'file_name': 'bdc_56_360114_3G_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '807350'},
#  {'file_id': 1442296,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '300',
#   'technology_code_desc': '3G',
#   'speed_tier': None,
#   'state_fips': '35',
#   'state_name': 'New Mexico',
#   'provider_id': '130886',
#   'provider_name': 'NE Colorado Cellular, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_35_130886_3G_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '1422'},
#  {'file_id': 1442464,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '300',
#   'technology_code_desc': '3G',
#   'speed_tier': None,
#   'state_fips': '49',
#   'state_name': 'Utah',
#   'provider_id': '360114',
#   'provider_name': 'Union Holding Corp.',
#   'file_type': 'gis',
#   'file_name': 'bdc_49_360114_3G_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '26156'},
#  {'file_id': 1442293,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '300',
#   'technology_code_desc': '3G',
#   'speed_tier': None,
#   'state_fips': '20',
#   'state_name': 'Kansas',
#   'provider_id': '130886',
#   'provider_name': 'NE Colorado Cellular, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_20_130886_3G_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '164292'},
#  {'file_id': 1442292,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '300',
#   'technology_code_desc': '3G',
#   'speed_tier': None,
#   'state_fips': '56',
#   'state_name': 'Wyoming',
#   'provider_id': '130886',
#   'provider_name': 'NE Colorado Cellular, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_56_130886_3G_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '13667'},
#  {'file_id': 1442334,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '300',
#   'technology_code_desc': '3G',
#   'speed_tier': None,
#   'state_fips': '35',
#   'state_name': 'New Mexico',
#   'provider_id': '131208',
#   'provider_name': 'Smith Bagley, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_35_131208_3G_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '1564'},
#  {'file_id': 1442333,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '300',
#   'technology_code_desc': '3G',
#   'speed_tier': None,
#   'state_fips': '49',
#   'state_name': 'Utah',
#   'provider_id': '131208',
#   'provider_name': 'Smith Bagley, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_49_131208_3G_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '3742'},
#  {'file_id': 1442456,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '300',
#   'technology_code_desc': '3G',
#   'speed_tier': None,
#   'state_fips': '42',
#   'state_name': 'Pennsylvania',
#   'provider_id': '300085',
#   'provider_name': 'Tower Bridge Mobile Holdings, LLC',
#   'file_type': 'gis',
#   'file_name': 'bdc_42_300085_3G_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '1091'},
#  {'file_id': 1442283,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '300',
#   'technology_code_desc': '3G',
#   'speed_tier': None,
#   'state_fips': '02',
#   'state_name': 'Alaska',
#   'provider_id': '130534',
#   'provider_name': 'GCI Holdings LLC',
#   'file_type': 'gis',
#   'file_name': 'bdc_02_130534_3G_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '1296648'},
#  {'file_id': 1442467,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '300',
#   'technology_code_desc': '3G',
#   'speed_tier': None,
#   'state_fips': '08',
#   'state_name': 'Colorado',
#   'provider_id': '360114',
#   'provider_name': 'Union Holding Corp.',
#   'file_type': 'gis',
#   'file_name': 'bdc_08_360114_3G_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '190349'},
#  {'file_id': 1442451,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '300',
#   'technology_code_desc': '3G',
#   'speed_tier': None,
#   'state_fips': '69',
#   'state_name': 'Commonwealth of the Northern Mariana Islands',
#   'provider_id': '220001',
#   'provider_name': 'PTI Pacifica Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_69_220001_3G_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '2159'},
#  {'file_id': 1442316,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '300',
#   'technology_code_desc': '3G',
#   'speed_tier': None,
#   'state_fips': '69',
#   'state_name': 'Commonwealth of the Northern Mariana Islands',
#   'provider_id': '130999',
#   'provider_name': 'NTT DoCoMo, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_69_130999_3G_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '1874'},
#  {'file_id': 1442222,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '300',
#   'technology_code_desc': '3G',
#   'speed_tier': None,
#   'state_fips': '78',
#   'state_name': 'United States Virgin Islands',
#   'provider_id': '130081',
#   'provider_name': 'ATN International, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_78_130081_3G_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '19197'},
#  {'file_id': 1442315,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '300',
#   'technology_code_desc': '3G',
#   'speed_tier': None,
#   'state_fips': '66',
#   'state_name': 'Guam',
#   'provider_id': '130999',
#   'provider_name': 'NTT DoCoMo, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_66_130999_3G_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '4185'},
#  {'file_id': 1442462,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '300',
#   'technology_code_desc': '3G',
#   'speed_tier': None,
#   'state_fips': '30',
#   'state_name': 'Montana',
#   'provider_id': '360114',
#   'provider_name': 'Union Holding Corp.',
#   'file_type': 'gis',
#   'file_name': 'bdc_30_360114_3G_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '14492'},
#  {'file_id': 1442463,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '300',
#   'technology_code_desc': '3G',
#   'speed_tier': None,
#   'state_fips': '16',
#   'state_name': 'Idaho',
#   'provider_id': '360114',
#   'provider_name': 'Union Holding Corp.',
#   'file_type': 'gis',
#   'file_name': 'bdc_16_360114_3G_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '18377'},
#  {'file_id': 1442310,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '47',
#   'state_name': 'Tennessee',
#   'provider_id': '130926',
#   'provider_name': 'North Carolina RSA 3 Cellular Telephone Company',
#   'file_type': 'gis',
#   'file_name': 'bdc_47_130926_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '13'},
#  {'file_id': 1442305,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '56',
#   'state_name': 'Wyoming',
#   'provider_id': '130890',
#   'provider_name': 'Nemont Telephone Cooperative, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_56_130890_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '3587'},
#  {'file_id': 1442307,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '38',
#   'state_name': 'North Dakota',
#   'provider_id': '130890',
#   'provider_name': 'Nemont Telephone Cooperative, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_38_130890_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '19034'},
#  {'file_id': 1442306,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '30',
#   'state_name': 'Montana',
#   'provider_id': '130890',
#   'provider_name': 'Nemont Telephone Cooperative, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_30_130890_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '371964'},
#  {'file_id': 1442297,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '29',
#   'state_name': 'Missouri',
#   'provider_id': '130886',
#   'provider_name': 'NE Colorado Cellular, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_29_130886_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '42'},
#  {'file_id': 1442299,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '40',
#   'state_name': 'Oklahoma',
#   'provider_id': '130886',
#   'provider_name': 'NE Colorado Cellular, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_40_130886_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '65'},
#  {'file_id': 1442300,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '35',
#   'state_name': 'New Mexico',
#   'provider_id': '130886',
#   'provider_name': 'NE Colorado Cellular, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_35_130886_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '54'},
#  {'file_id': 1442304,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '08',
#   'state_name': 'Colorado',
#   'provider_id': '130886',
#   'provider_name': 'NE Colorado Cellular, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_08_130886_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '288519'},
#  {'file_id': 1442286,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '78',
#   'state_name': 'United States Virgin Islands',
#   'provider_id': '130741',
#   'provider_name': 'Liberty Latin America Ltd.',
#   'file_type': 'gis',
#   'file_name': 'bdc_78_130741_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '1111'},
#  {'file_id': 1442376,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '41',
#   'state_name': 'Oregon',
#   'provider_id': '131310',
#   'provider_name': 'Telephone and Data Systems, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_41_131310_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '447346'},
#  {'file_id': 1442188,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '05',
#   'state_name': 'Arkansas',
#   'provider_id': '130077',
#   'provider_name': 'AT&T Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_05_130077_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '945751'},
#  {'file_id': 1442235,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '53',
#   'state_name': 'Washington',
#   'provider_id': '130403',
#   'provider_name': 'T-Mobile USA, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_53_130403_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '973556'},
#  {'file_id': 1442183,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '18',
#   'state_name': 'Indiana',
#   'provider_id': '130077',
#   'provider_name': 'AT&T Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_18_130077_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '857006'},
#  {'file_id': 1442215,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '32',
#   'state_name': 'Nevada',
#   'provider_id': '130077',
#   'provider_name': 'AT&T Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_32_130077_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '1329887'},
#  {'file_id': 1442207,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '24',
#   'state_name': 'Maryland',
#   'provider_id': '130077',
#   'provider_name': 'AT&T Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_24_130077_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '233203'},
#  {'file_id': 1442192,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '16',
#   'state_name': 'Idaho',
#   'provider_id': '130077',
#   'provider_name': 'AT&T Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_16_130077_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '943817'},
#  {'file_id': 1442217,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '34',
#   'state_name': 'New Jersey',
#   'provider_id': '130077',
#   'provider_name': 'AT&T Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_34_130077_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '183163'},
#  {'file_id': 1442197,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '50',
#   'state_name': 'Vermont',
#   'provider_id': '130077',
#   'provider_name': 'AT&T Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_50_130077_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '147008'},
#  {'file_id': 1442289,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '48',
#   'state_name': 'Texas',
#   'provider_id': '130794',
#   'provider_name': 'NBVDS Investment, LLC',
#   'file_type': 'gis',
#   'file_name': 'bdc_48_130794_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '400'},
#  {'file_id': 1442288,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '05',
#   'state_name': 'Arkansas',
#   'provider_id': '130794',
#   'provider_name': 'NBVDS Investment, LLC',
#   'file_type': 'gis',
#   'file_name': 'bdc_05_130794_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '69'},
#  {'file_id': 1442189,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '04',
#   'state_name': 'Arizona',
#   'provider_id': '130077',
#   'provider_name': 'AT&T Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_04_130077_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '1531852'},
#  {'file_id': 1442287,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '72',
#   'state_name': 'Puerto Rico',
#   'provider_id': '130741',
#   'provider_name': 'Liberty Latin America Ltd.',
#   'file_type': 'gis',
#   'file_name': 'bdc_72_130741_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '12656'},
#  {'file_id': 1442485,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '31',
#   'state_name': 'Nebraska',
#   'provider_id': '460631',
#   'provider_name': 'Nex-Tech Wireless',
#   'file_type': 'gis',
#   'file_name': 'bdc_31_460631_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '4196'},
#  {'file_id': 1442487,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '08',
#   'state_name': 'Colorado',
#   'provider_id': '460631',
#   'provider_name': 'Nex-Tech Wireless',
#   'file_type': 'gis',
#   'file_name': 'bdc_08_460631_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '6895'},
#  {'file_id': 1442201,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '38',
#   'state_name': 'North Dakota',
#   'provider_id': '130077',
#   'provider_name': 'AT&T Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_38_130077_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '1558281'},
#  {'file_id': 1442233,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '49',
#   'state_name': 'Utah',
#   'provider_id': '130403',
#   'provider_name': 'T-Mobile USA, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_49_130403_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '839058'},
#  {'file_id': 1442252,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '12',
#   'state_name': 'Florida',
#   'provider_id': '130403',
#   'provider_name': 'T-Mobile USA, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_12_130403_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '1063098'},
#  {'file_id': 1442261,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '10',
#   'state_name': 'Delaware',
#   'provider_id': '130403',
#   'provider_name': 'T-Mobile USA, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_10_130403_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '45404'},
#  {'file_id': 1442271,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '26',
#   'state_name': 'Michigan',
#   'provider_id': '130403',
#   'provider_name': 'T-Mobile USA, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_26_130403_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '785506'},
#  {'file_id': 1442349,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '01',
#   'state_name': 'Alabama',
#   'provider_id': '131302',
#   'provider_name': 'Telapex, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_01_131302_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '10104'},
#  {'file_id': 1442239,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '50',
#   'state_name': 'Vermont',
#   'provider_id': '130403',
#   'provider_name': 'T-Mobile USA, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_50_130403_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '91932'},
#  {'file_id': 1442240,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '15',
#   'state_name': 'Hawaii',
#   'provider_id': '130403',
#   'provider_name': 'T-Mobile USA, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_15_130403_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '59843'},
#  {'file_id': 1442347,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '47',
#   'state_name': 'Tennessee',
#   'provider_id': '131227',
#   'provider_name': 'Southern Company',
#   'file_type': 'gis',
#   'file_name': 'bdc_47_131227_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '517'},
#  {'file_id': 1442345,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '37',
#   'state_name': 'North Carolina',
#   'provider_id': '131227',
#   'provider_name': 'Southern Company',
#   'file_type': 'gis',
#   'file_name': 'bdc_37_131227_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '546'},
#  {'file_id': 1442199,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '53',
#   'state_name': 'Washington',
#   'provider_id': '130077',
#   'provider_name': 'AT&T Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_53_130077_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '1082346'},
#  {'file_id': 1442230,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '16',
#   'state_name': 'Idaho',
#   'provider_id': '130403',
#   'provider_name': 'T-Mobile USA, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_16_130403_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '785354'},
#  {'file_id': 1442328,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '16',
#   'state_name': 'Idaho',
#   'provider_id': '131190',
#   'provider_name': 'Horizon Communications, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_16_131190_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '15053'},
#  {'file_id': 1442169,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '26',
#   'state_name': 'Michigan',
#   'provider_id': '130018',
#   'provider_name': 'Agri-Valley Communications, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_26_130018_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '63886'},
#  {'file_id': 1442280,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '16',
#   'state_name': 'Idaho',
#   'provider_id': '130431',
#   'provider_name': 'Eagle Telephone Systems, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_16_130431_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '7835'},
#  {'file_id': 1442243,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '06',
#   'state_name': 'California',
#   'provider_id': '130403',
#   'provider_name': 'T-Mobile USA, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_06_130403_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '1892120'},
#  {'file_id': 1442278,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '11',
#   'state_name': 'District of Columbia',
#   'provider_id': '130403',
#   'provider_name': 'T-Mobile USA, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_11_130403_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '1723'},
#  {'file_id': 1442237,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '30',
#   'state_name': 'Montana',
#   'provider_id': '130403',
#   'provider_name': 'T-Mobile USA, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_30_130403_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '1571830'},
#  {'file_id': 1442191,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '30',
#   'state_name': 'Montana',
#   'provider_id': '130077',
#   'provider_name': 'AT&T Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_30_130077_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '1609187'},
#  {'file_id': 1442227,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '30',
#   'state_name': 'Montana',
#   'provider_id': '130378',
#   'provider_name': 'Custer Telephone Cooperative Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_30_130378_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '3'},
#  {'file_id': 1442226,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '16',
#   'state_name': 'Idaho',
#   'provider_id': '130378',
#   'provider_name': 'Custer Telephone Cooperative Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_16_130378_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '34215'},
#  {'file_id': 1442257,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '33',
#   'state_name': 'New Hampshire',
#   'provider_id': '130403',
#   'provider_name': 'T-Mobile USA, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_33_130403_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '128290'},
#  {'file_id': 1442225,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '02',
#   'state_name': 'Alaska',
#   'provider_id': '130352',
#   'provider_name': 'Cordova Telephone Cooperative, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_02_130352_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '61483'},
#  {'file_id': 1442397,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '23',
#   'state_name': 'Maine',
#   'provider_id': '131425',
#   'provider_name': 'Verizon Communications Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_23_131425_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '442775'},
#  {'file_id': 1442404,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '18',
#   'state_name': 'Indiana',
#   'provider_id': '131425',
#   'provider_name': 'Verizon Communications Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_18_131425_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '893595'},
#  {'file_id': 1442326,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '05',
#   'state_name': 'Arkansas',
#   'provider_id': '131039',
#   'provider_name': 'Pine Telephone Company',
#   'file_type': 'gis',
#   'file_name': 'bdc_05_131039_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '16716'},
#  {'file_id': 1442281,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '41',
#   'state_name': 'Oregon',
#   'provider_id': '130431',
#   'provider_name': 'Eagle Telephone Systems, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_41_130431_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '32585'},
#  {'file_id': 1442208,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '22',
#   'state_name': 'Louisiana',
#   'provider_id': '130077',
#   'provider_name': 'AT&T Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_22_130077_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '968528'},
#  {'file_id': 1442416,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '48',
#   'state_name': 'Texas',
#   'provider_id': '131425',
#   'provider_name': 'Verizon Communications Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_48_131425_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '4949229'},
#  {'file_id': 1442224,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '02',
#   'state_name': 'Alaska',
#   'provider_id': '130349',
#   'provider_name': 'Copper Valley Telephone Cooperative',
#   'file_type': 'gis',
#   'file_name': 'bdc_02_130349_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '174277'},
#  {'file_id': 1442231,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '56',
#   'state_name': 'Wyoming',
#   'provider_id': '130403',
#   'provider_name': 'T-Mobile USA, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_56_130403_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '1000644'},
#  {'file_id': 1442232,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '72',
#   'state_name': 'Puerto Rico',
#   'provider_id': '130403',
#   'provider_name': 'T-Mobile USA, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_72_130403_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '109979'},
#  {'file_id': 1442357,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '06',
#   'state_name': 'California',
#   'provider_id': '131310',
#   'provider_name': 'Telephone and Data Systems, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_06_131310_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '175234'},
#  {'file_id': 1442277,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '54',
#   'state_name': 'West Virginia',
#   'provider_id': '130403',
#   'provider_name': 'T-Mobile USA, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_54_130403_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '242942'},
#  {'file_id': 1442373,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '19',
#   'state_name': 'Iowa',
#   'provider_id': '131310',
#   'provider_name': 'Telephone and Data Systems, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_19_131310_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '1090251'},
#  {'file_id': 1442363,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '20',
#   'state_name': 'Kansas',
#   'provider_id': '131310',
#   'provider_name': 'Telephone and Data Systems, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_20_131310_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '435093'},
#  {'file_id': 1442321,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '48',
#   'state_name': 'Texas',
#   'provider_id': '131007',
#   'provider_name': 'Panhandle Telephone Cooperative, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_48_131007_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '20'},
#  {'file_id': 1442356,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '53',
#   'state_name': 'Washington',
#   'provider_id': '131310',
#   'provider_name': 'Telephone and Data Systems, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_53_131310_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '243232'},
#  {'file_id': 1442168,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '02',
#   'state_name': 'Alaska',
#   'provider_id': '130011',
#   'provider_name': 'Adak Eagle Enterprises, LLC',
#   'file_type': 'gis',
#   'file_name': 'bdc_02_130011_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '6098'},
#  {'file_id': 1442284,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '02',
#   'state_name': 'Alaska',
#   'provider_id': '130534',
#   'provider_name': 'GCI Holdings LLC',
#   'file_type': 'gis',
#   'file_name': 'bdc_02_130534_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '270295'},
#  {'file_id': 1442170,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '02',
#   'state_name': 'Alaska',
#   'provider_id': '130067',
#   'provider_name': 'Arctic Slope Telephone Association Cooperative, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_02_130067_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '124526'},
#  {'file_id': 1442209,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '25',
#   'state_name': 'Massachusetts',
#   'provider_id': '130077',
#   'provider_name': 'AT&T Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_25_130077_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '182487'},
#  {'file_id': 1442223,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '78',
#   'state_name': 'United States Virgin Islands',
#   'provider_id': '130081',
#   'provider_name': 'ATN International, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_78_130081_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '18950'},
#  {'file_id': 1442202,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '41',
#   'state_name': 'Oregon',
#   'provider_id': '130077',
#   'provider_name': 'AT&T Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_41_130077_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '1357234'},
#  {'file_id': 1442193,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '15',
#   'state_name': 'Hawaii',
#   'provider_id': '130077',
#   'provider_name': 'AT&T Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_15_130077_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '86892'},
#  {'file_id': 1442194,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '46',
#   'state_name': 'South Dakota',
#   'provider_id': '130077',
#   'provider_name': 'AT&T Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_46_130077_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '1687589'},
#  {'file_id': 1442219,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '55',
#   'state_name': 'Wisconsin',
#   'provider_id': '130077',
#   'provider_name': 'AT&T Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_55_130077_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '947186'},
#  {'file_id': 1442319,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '40',
#   'state_name': 'Oklahoma',
#   'provider_id': '131007',
#   'provider_name': 'Panhandle Telephone Cooperative, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_40_131007_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '128633'},
#  {'file_id': 1442210,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '12',
#   'state_name': 'Florida',
#   'provider_id': '130077',
#   'provider_name': 'AT&T Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_12_130077_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '1308331'},
#  {'file_id': 1442182,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '19',
#   'state_name': 'Iowa',
#   'provider_id': '130077',
#   'provider_name': 'AT&T Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_19_130077_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '1064841'},
#  {'file_id': 1442385,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '21',
#   'state_name': 'Kentucky',
#   'provider_id': '131328',
#   'provider_name': 'Thacker-Grigsby Telephone Company, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_21_131328_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '173538'},
#  {'file_id': 1442266,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '05',
#   'state_name': 'Arkansas',
#   'provider_id': '130403',
#   'provider_name': 'T-Mobile USA, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_05_130403_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '638903'},
#  {'file_id': 1442285,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '46',
#   'state_name': 'South Dakota',
#   'provider_id': '130673',
#   'provider_name': 'James Valley Cooperative Telephone Company',
#   'file_type': 'gis',
#   'file_name': 'bdc_46_130673_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '152983'},
#  {'file_id': 1442377,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '40',
#   'state_name': 'Oklahoma',
#   'provider_id': '131310',
#   'provider_name': 'Telephone and Data Systems, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_40_131310_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '539128'},
#  {'file_id': 1442418,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
#   'technology_code_desc': '4G LTE',
#   'speed_tier': None,
#   'state_fips': '13',
#   'state_name': 'Georgia',
#   'provider_id': '131425',
#   'provider_name': 'Verizon Communications Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_13_131425_4GLTE_mobile_broadband_h3_J25_03feb2026',
#   'record_count': '1490809'},
#  {'file_id': 1442443,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Broadband',
#   'technology_code': '400',
# ...
#   'record_count': '68003'},
#  {'file_id': 1443009,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Voice',
#   'technology_code': '999',
#   'technology_code_desc': 'Mobile Voice',
#   'speed_tier': None,
#   'state_fips': '02',
#   'state_name': 'Alaska',
#   'provider_id': '130077',
#   'provider_name': 'AT&T Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_02_130077_MobileVoice_mobile_voice_h3_J25_03feb2026',
#   'record_count': '1380648'},
#  {'file_id': 1443303,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Voice',
#   'technology_code': '999',
#   'technology_code_desc': 'Mobile Voice',
#   'speed_tier': None,
#   'state_fips': '33',
#   'state_name': 'New Hampshire',
#   'provider_id': '460632',
#   'provider_name': 'VTel Wireless, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_33_460632_MobileVoice_mobile_voice_h3_J25_03feb2026',
#   'record_count': '2772'},
#  {'file_id': 1443353,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Voice',
#   'technology_code': '999',
#   'technology_code_desc': 'Mobile Voice',
#   'speed_tier': None,
#   'state_fips': '42',
#   'state_name': 'Pennsylvania',
#   'provider_id': '460677',
#   'provider_name': 'Dish Network Corporation',
#   'file_type': 'gis',
#   'file_name': 'bdc_42_460677_MobileVoice_mobile_voice_h3_J25_03feb2026',
#   'record_count': '420386'},
#  {'file_id': 1443321,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Voice',
#   'technology_code': '999',
#   'technology_code_desc': 'Mobile Voice',
#   'speed_tier': None,
#   'state_fips': '26',
#   'state_name': 'Michigan',
#   'provider_id': '460677',
#   'provider_name': 'Dish Network Corporation',
#   'file_type': 'gis',
#   'file_name': 'bdc_26_460677_MobileVoice_mobile_voice_h3_J25_03feb2026',
#   'record_count': '350766'},
#  {'file_id': 1443323,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Voice',
#   'technology_code': '999',
#   'technology_code_desc': 'Mobile Voice',
#   'speed_tier': None,
#   'state_fips': '25',
#   'state_name': 'Massachusetts',
#   'provider_id': '460677',
#   'provider_name': 'Dish Network Corporation',
#   'file_type': 'gis',
#   'file_name': 'bdc_25_460677_MobileVoice_mobile_voice_h3_J25_03feb2026',
#   'record_count': '173880'},
#  {'file_id': 1443344,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Voice',
#   'technology_code': '999',
#   'technology_code_desc': 'Mobile Voice',
#   'speed_tier': None,
#   'state_fips': '49',
#   'state_name': 'Utah',
#   'provider_id': '460677',
#   'provider_name': 'Dish Network Corporation',
#   'file_type': 'gis',
#   'file_name': 'bdc_49_460677_MobileVoice_mobile_voice_h3_J25_03feb2026',
#   'record_count': '93969'},
#  {'file_id': 1443053,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Voice',
#   'technology_code': '999',
#   'technology_code_desc': 'Mobile Voice',
#   'speed_tier': None,
#   'state_fips': '37',
#   'state_name': 'North Carolina',
#   'provider_id': '130077',
#   'provider_name': 'AT&T Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_37_130077_MobileVoice_mobile_voice_h3_J25_03feb2026',
#   'record_count': '1297792'},
#  {'file_id': 1443319,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Voice',
#   'technology_code': '999',
#   'technology_code_desc': 'Mobile Voice',
#   'speed_tier': None,
#   'state_fips': '24',
#   'state_name': 'Maryland',
#   'provider_id': '460677',
#   'provider_name': 'Dish Network Corporation',
#   'file_type': 'gis',
#   'file_name': 'bdc_24_460677_MobileVoice_mobile_voice_h3_J25_03feb2026',
#   'record_count': '182511'},
#  {'file_id': 1443302,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Voice',
#   'technology_code': '999',
#   'technology_code_desc': 'Mobile Voice',
#   'speed_tier': None,
#   'state_fips': '25',
#   'state_name': 'Massachusetts',
#   'provider_id': '460632',
#   'provider_name': 'VTel Wireless, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_25_460632_MobileVoice_mobile_voice_h3_J25_03feb2026',
#   'record_count': '2'},
#  {'file_id': 1443300,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Voice',
#   'technology_code': '999',
#   'technology_code_desc': 'Mobile Voice',
#   'speed_tier': None,
#   'state_fips': '08',
#   'state_name': 'Colorado',
#   'provider_id': '460631',
#   'provider_name': 'Nex-Tech Wireless',
#   'file_type': 'gis',
#   'file_name': 'bdc_08_460631_MobileVoice_mobile_voice_h3_J25_03feb2026',
#   'record_count': '4768'},
#  {'file_id': 1443016,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Voice',
#   'technology_code': '999',
#   'technology_code_desc': 'Mobile Voice',
#   'speed_tier': None,
#   'state_fips': '19',
#   'state_name': 'Iowa',
#   'provider_id': '130077',
#   'provider_name': 'AT&T Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_19_130077_MobileVoice_mobile_voice_h3_J25_03feb2026',
#   'record_count': '1339480'},
#  {'file_id': 1443028,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Voice',
#   'technology_code': '999',
#   'technology_code_desc': 'Mobile Voice',
#   'speed_tier': None,
#   'state_fips': '44',
#   'state_name': 'Rhode Island',
#   'provider_id': '130077',
#   'provider_name': 'AT&T Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_44_130077_MobileVoice_mobile_voice_h3_J25_03feb2026',
#   'record_count': '26205'},
#  {'file_id': 1443301,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Voice',
#   'technology_code': '999',
#   'technology_code_desc': 'Mobile Voice',
#   'speed_tier': None,
#   'state_fips': '20',
#   'state_name': 'Kansas',
#   'provider_id': '460631',
#   'provider_name': 'Nex-Tech Wireless',
#   'file_type': 'gis',
#   'file_name': 'bdc_20_460631_MobileVoice_mobile_voice_h3_J25_03feb2026',
#   'record_count': '725256'},
#  {'file_id': 1443299,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Voice',
#   'technology_code': '999',
#   'technology_code_desc': 'Mobile Voice',
#   'speed_tier': None,
#   'state_fips': '31',
#   'state_name': 'Nebraska',
#   'provider_id': '460631',
#   'provider_name': 'Nex-Tech Wireless',
#   'file_type': 'gis',
#   'file_name': 'bdc_31_460631_MobileVoice_mobile_voice_h3_J25_03feb2026',
#   'record_count': '2096'},
#  {'file_id': 1443012,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Voice',
#   'technology_code': '999',
#   'technology_code_desc': 'Mobile Voice',
#   'speed_tier': None,
#   'state_fips': '36',
#   'state_name': 'New York',
#   'provider_id': '130077',
#   'provider_name': 'AT&T Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_36_130077_MobileVoice_mobile_voice_h3_J25_03feb2026',
#   'record_count': '1055680'},
#  {'file_id': 1443051,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Voice',
#   'technology_code': '999',
#   'technology_code_desc': 'Mobile Voice',
#   'speed_tier': None,
#   'state_fips': '11',
#   'state_name': 'District of Columbia',
#   'provider_id': '130077',
#   'provider_name': 'AT&T Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_11_130077_MobileVoice_mobile_voice_h3_J25_03feb2026',
#   'record_count': '1730'},
#  {'file_id': 1443018,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Voice',
#   'technology_code': '999',
#   'technology_code_desc': 'Mobile Voice',
#   'speed_tier': None,
#   'state_fips': '25',
#   'state_name': 'Massachusetts',
#   'provider_id': '130077',
#   'provider_name': 'AT&T Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_25_130077_MobileVoice_mobile_voice_h3_J25_03feb2026',
#   'record_count': '192507'},
#  {'file_id': 1443007,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Voice',
#   'technology_code': '999',
#   'technology_code_desc': 'Mobile Voice',
#   'speed_tier': None,
#   'state_fips': '12',
#   'state_name': 'Florida',
#   'provider_id': '130077',
#   'provider_name': 'AT&T Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_12_130077_MobileVoice_mobile_voice_h3_J25_03feb2026',
#   'record_count': '1471308'},
#  {'file_id': 1443038,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Voice',
#   'technology_code': '999',
#   'technology_code_desc': 'Mobile Voice',
#   'speed_tier': None,
#   'state_fips': '49',
#   'state_name': 'Utah',
#   'provider_id': '130077',
#   'provider_name': 'AT&T Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_49_130077_MobileVoice_mobile_voice_h3_J25_03feb2026',
#   'record_count': '1510322'},
#  {'file_id': 1443022,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Voice',
#   'technology_code': '999',
#   'technology_code_desc': 'Mobile Voice',
#   'speed_tier': None,
#   'state_fips': '18',
#   'state_name': 'Indiana',
#   'provider_id': '130077',
#   'provider_name': 'AT&T Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_18_130077_MobileVoice_mobile_voice_h3_J25_03feb2026',
#   'record_count': '906544'},
#  {'file_id': 1443013,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Voice',
#   'technology_code': '999',
#   'technology_code_desc': 'Mobile Voice',
#   'speed_tier': None,
#   'state_fips': '08',
#   'state_name': 'Colorado',
#   'provider_id': '130077',
#   'provider_name': 'AT&T Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_08_130077_MobileVoice_mobile_voice_h3_J25_03feb2026',
#   'record_count': '1940947'},
#  {'file_id': 1443141,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Voice',
#   'technology_code': '999',
#   'technology_code_desc': 'Mobile Voice',
#   'speed_tier': None,
#   'state_fips': '55',
#   'state_name': 'Wisconsin',
#   'provider_id': '130937',
#   'provider_name': 'Northeast Communications of Wisconsin, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_55_130937_MobileVoice_mobile_voice_h3_J25_03feb2026',
#   'record_count': '500514'},
#  {'file_id': 1443040,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Voice',
#   'technology_code': '999',
#   'technology_code_desc': 'Mobile Voice',
#   'speed_tier': None,
#   'state_fips': '46',
#   'state_name': 'South Dakota',
#   'provider_id': '130077',
#   'provider_name': 'AT&T Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_46_130077_MobileVoice_mobile_voice_h3_J25_03feb2026',
#   'record_count': '1869956'},
#  {'file_id': 1443305,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Voice',
#   'technology_code': '999',
#   'technology_code_desc': 'Mobile Voice',
#   'speed_tier': None,
#   'state_fips': '36',
#   'state_name': 'New York',
#   'provider_id': '460632',
#   'provider_name': 'VTel Wireless, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_36_460632_MobileVoice_mobile_voice_h3_J25_03feb2026',
#   'record_count': '1185'},
#  {'file_id': 1443326,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Voice',
#   'technology_code': '999',
#   'technology_code_desc': 'Mobile Voice',
#   'speed_tier': None,
#   'state_fips': '30',
#   'state_name': 'Montana',
#   'provider_id': '460677',
#   'provider_name': 'Dish Network Corporation',
#   'file_type': 'gis',
#   'file_name': 'bdc_30_460677_MobileVoice_mobile_voice_h3_J25_03feb2026',
#   'record_count': '68806'},
#  {'file_id': 1443332,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Voice',
#   'technology_code': '999',
#   'technology_code_desc': 'Mobile Voice',
#   'speed_tier': None,
#   'state_fips': '38',
#   'state_name': 'North Dakota',
#   'provider_id': '460677',
#   'provider_name': 'Dish Network Corporation',
#   'file_type': 'gis',
#   'file_name': 'bdc_38_460677_MobileVoice_mobile_voice_h3_J25_03feb2026',
#   'record_count': '41612'},
#  {'file_id': 1443029,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Voice',
#   'technology_code': '999',
#   'technology_code_desc': 'Mobile Voice',
#   'speed_tier': None,
#   'state_fips': '01',
#   'state_name': 'Alabama',
#   'provider_id': '130077',
#   'provider_name': 'AT&T Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_01_130077_MobileVoice_mobile_voice_h3_J25_03feb2026',
#   'record_count': '1244432'},
#  {'file_id': 1443027,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Voice',
#   'technology_code': '999',
#   'technology_code_desc': 'Mobile Voice',
#   'speed_tier': None,
#   'state_fips': '04',
#   'state_name': 'Arizona',
#   'provider_id': '130077',
#   'provider_name': 'AT&T Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_04_130077_MobileVoice_mobile_voice_h3_J25_03feb2026',
#   'record_count': '2035190'},
#  {'file_id': 1443043,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Voice',
#   'technology_code': '999',
#   'technology_code_desc': 'Mobile Voice',
#   'speed_tier': None,
#   'state_fips': '23',
#   'state_name': 'Maine',
#   'provider_id': '130077',
#   'provider_name': 'AT&T Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_23_130077_MobileVoice_mobile_voice_h3_J25_03feb2026',
#   'record_count': '425631'},
#  {'file_id': 1443149,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Voice',
#   'technology_code': '999',
#   'technology_code_desc': 'Mobile Voice',
#   'speed_tier': None,
#   'state_fips': '35',
#   'state_name': 'New Mexico',
#   'provider_id': '131007',
#   'provider_name': 'Panhandle Telephone Cooperative, Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_35_131007_MobileVoice_mobile_voice_h3_J25_03feb2026',
#   'record_count': '3'},
#  {'file_id': 1443320,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Voice',
#   'technology_code': '999',
#   'technology_code_desc': 'Mobile Voice',
#   'speed_tier': None,
#   'state_fips': '29',
#   'state_name': 'Missouri',
#   'provider_id': '460677',
#   'provider_name': 'Dish Network Corporation',
#   'file_type': 'gis',
#   'file_name': 'bdc_29_460677_MobileVoice_mobile_voice_h3_J25_03feb2026',
#   'record_count': '136337'},
#  {'file_id': 1443045,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Voice',
#   'technology_code': '999',
#   'technology_code_desc': 'Mobile Voice',
#   'speed_tier': None,
#   'state_fips': '40',
#   'state_name': 'Oklahoma',
#   'provider_id': '130077',
#   'provider_name': 'AT&T Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_40_130077_MobileVoice_mobile_voice_h3_J25_03feb2026',
#   'record_count': '1514406'},
#  {'file_id': 1443025,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Voice',
#   'technology_code': '999',
#   'technology_code_desc': 'Mobile Voice',
#   'speed_tier': None,
#   'state_fips': '15',
#   'state_name': 'Hawaii',
#   'provider_id': '130077',
#   'provider_name': 'AT&T Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_15_130077_MobileVoice_mobile_voice_h3_J25_03feb2026',
#   'record_count': '116876'},
#  {'file_id': 1443035,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Voice',
#   'technology_code': '999',
#   'technology_code_desc': 'Mobile Voice',
#   'speed_tier': None,
#   'state_fips': '34',
#   'state_name': 'New Jersey',
#   'provider_id': '130077',
#   'provider_name': 'AT&T Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_34_130077_MobileVoice_mobile_voice_h3_J25_03feb2026',
#   'record_count': '186710'},
#  {'file_id': 1443017,
#   'category': 'Provider',
#   'subcategory': 'Hexagon Coverage',
#   'technology_type': 'Mobile Voice',
#   'technology_code': '999',
#   'technology_code_desc': 'Mobile Voice',
#   'speed_tier': None,
#   'state_fips': '42',
#   'state_name': 'Pennsylvania',
#   'provider_id': '130077',
#   'provider_name': 'AT&T Inc.',
#   'file_type': 'gis',
#   'file_name': 'bdc_42_130077_MobileVoice_mobile_voice_h3_J25_03feb2026',
#   'record_count': '1042130'},
#  ...]

# %%
import pandas as pd
import os

# Convert to DataFrame and save as CSV
df = pd.DataFrame(filtered_records)
filename = "mobile_datasets.csv"
pathout = "scraped_data\\mno" # Update this storage location
df_filtered = df[
    (df["state_name"].isin(["Pennsylvania", "New York", "New Jersey"])) & # extract our states of interest
    (df["technology_code_desc"] == "5G-NR") & # limit the tech
    (df["provider_name"] == 'AT&T Inc.') # single out a provider 
]

df_filtered.to_csv(os.path.join(pathout, filename), index=False)

print(f"Saved {len(df_filtered)} records to provider_hexagon_coverage.csv")
df_filtered.head()
# Out:
# Saved 6 records to provider_hexagon_coverage.csv
#      file_id  category       subcategory   technology_type technology_code  \
# 525  1442799  Provider  Hexagon Coverage  Mobile Broadband             500
# 536  1442770  Provider  Hexagon Coverage  Mobile Broadband             500
# 547  1442757  Provider  Hexagon Coverage  Mobile Broadband             500
# 806  1442513  Provider  Hexagon Coverage  Mobile Broadband             500
# 811  1442504  Provider  Hexagon Coverage  Mobile Broadband             500
#
#     technology_code_desc speed_tier state_fips    state_name provider_id  \
# 525                5G-NR       35/3         36      New York      130077
# 536                5G-NR       35/3         34    New Jersey      130077
# 547                5G-NR       35/3         42  Pennsylvania      130077
# 806                5G-NR        7/1         42  Pennsylvania      130077
# 811                5G-NR        7/1         34    New Jersey      130077
#
#     provider_name file_type  \
# 525     AT&T Inc.       gis
# 536     AT&T Inc.       gis
# 547     AT&T Inc.       gis
# 806     AT&T Inc.       gis
# 811     AT&T Inc.       gis
#
#                                              file_name record_count
# 525  bdc_36_130077_5GNR_35_3_mobile_broadband_h3_J2...       458950
# 536  bdc_34_130077_5GNR_35_3_mobile_broadband_h3_J2...       106481
# 547  bdc_42_130077_5GNR_35_3_mobile_broadband_h3_J2...       537862
# 806  bdc_42_130077_5GNR_7_1_mobile_broadband_h3_J25...       667395
# 811  bdc_34_130077_5GNR_7_1_mobile_broadband_h3_J25...       155273

# %%
# Stepping stone create the list of ID's necessary for the url

import csv

pathout = "scraped_data\\mno" # Update this storage location to match above

with open(os.path.join(pathout, filename),'r') as f:
    m = list(csv.reader(f))

list_of_urls = list()

for i,x in enumerate(m):
    if i > 0:
        list_of_urls.append(x[0])

# %%
import requests
import zipfile
import os
from pathlib import Path
import geopandas as gpd
import tempfile
import pandas as pd
from datetime import datetime
import traceback

OUT_DIR = Path("../scraped_data/mno/att")

def download_and_process_fcc_data(file_id, username, hash_value, out_dir=OUT_DIR):
    download_dir = Path(tempfile.mkdtemp())
    zip_path     = download_dir / f"data_{file_id.replace('/', '_')}.zip"
    extract_path = download_dir / f"extracted_{file_id.replace('/', '_')}"
    out_dir      = Path(out_dir)
    out_dir.mkdir(parents=True, exist_ok=True)

    try:
        # Step 1: Download
        print(f"Downloading file {file_id}...")
        url = f'https://bdc.fcc.gov/api/public/map/downloads/downloadFile/availability/{file_id}/2'
        headers = {
            'username': username,
            'hash_value': hash_value,
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36',
            'Accept': 'application/json',
            'Connection': 'close'
        }

        session = requests.Session()
        session.mount('https://', requests.adapters.HTTPAdapter(max_retries=3))
        response = session.get(url, headers=headers, stream=True, timeout=(30, 300))
        response.raise_for_status()

        total_size = int(response.headers.get('content-length', 0))
        downloaded = 0
        with open(zip_path, 'wb') as f:
            for chunk in response.iter_content(chunk_size=1024*1024):
                if chunk:
                    f.write(chunk)
                    downloaded += len(chunk)
                    if total_size:
                        print(f"Progress: {(downloaded/total_size)*100:.1f}% ({downloaded/(1024*1024):.1f} MB)", end='\r')
        print(f"\nDownloaded ({downloaded/(1024*1024):.1f} MB)")

        # Step 2: Extract
        print("Extracting...")
        os.makedirs(extract_path, exist_ok=True)
        with zipfile.ZipFile(zip_path, 'r') as zip_ref:
            zip_ref.extractall(extract_path)

        # Step 3: Find geopackage
        gpkg_files = list(extract_path.glob("*.gpkg"))
        if not gpkg_files:
            raise FileNotFoundError("No .gpkg file found in extracted data")
        print(f"Found geopackage: {gpkg_files[0].name}")

        # Step 4: Read and drop geometry
        gdf = gpd.read_file(gpkg_files[0])
        df  = gdf.drop(columns="geometry")
        print(f"Loaded {len(df)} rows, {len(df.columns)} columns")

        # Step 5: Save to CSV
        csv_path = out_dir / f"{file_id.replace('/', '_')}.csv"
        df.to_csv(csv_path, index=False)
        print(f"Saved to {csv_path}")

        return {
            'file_id': file_id,
            'status': 'success',
            'rows': len(df),
            'columns': len(df.columns),
            'file_size_mb': downloaded / (1024*1024),
            'csv_path': str(csv_path),
            'error_message': None,
            'timestamp': datetime.now().isoformat()
        }

    except Exception as e:
        print(f"ERROR processing {file_id}: {e}")
        return {
            'file_id': file_id,
            'status': 'failed',
            'rows': 0,
            'columns': 0,
            'file_size_mb': 0,
            'csv_path': None,
            'error_message': str(e),
            'error_trace': traceback.format_exc(),
            'timestamp': datetime.now().isoformat()
        }

    finally:
        import shutil
        if zip_path.exists():    zip_path.unlink()
        if extract_path.exists(): shutil.rmtree(extract_path)

# Serves two purposes, saves progress in case of mishap during the long process and 
# shows imitation progress bar
def process_batch_downloads(list_of_urls, username, hash_value, out_dir=OUT_DIR):
    results = []
    total   = len(list_of_urls)
    results_csv = Path(out_dir) / "download_results.csv"

    print(f"Starting batch download of {total} files → {out_dir}")
    print("=" * 80)

    for idx, file_id in enumerate(list_of_urls, 1):
        print(f"\n[{idx}/{total}] Processing: {file_id}")
        print("-" * 80)

        result = download_and_process_fcc_data(file_id, username, hash_value, out_dir)
        results.append(result)

        # Save results log after each file
        pd.DataFrame(results).to_csv(results_csv, index=False)
        print(f"Status: {result['status'].upper()}")

    df_results = pd.DataFrame(results)
    print("\n" + "=" * 80)
    print(f"Complete — {len(df_results[df_results['status']=='success'])}/{total} succeeded")
    print(f"Total rows saved: {df_results['rows'].sum()}")
    print(f"Results log: {results_csv}")

    failed = df_results[df_results['status'] == 'failed']
    if len(failed):
        print("\nFailed files:")
        for _, row in failed.iterrows():
            print(f"  - {row['file_id']}: {row['error_message']}")

    return df_results


# Usage
USERNAME   = os.environ["FCC_USERNAME"]
HASH_VALUE = os.environ["FCC_HASH_VALUE"]

results_df = process_batch_downloads(
    list_of_urls=list_of_urls,
    username=USERNAME,
    hash_value=HASH_VALUE
)
# Out:
# Starting batch download of 6 files → ..\scraped_data\mno\att
# ================================================================================
#
# [1/6] Processing: 1442799
# --------------------------------------------------------------------------------
# Downloading file 1442799...
# Progress: 100.0% (38.1 MB)
# Downloaded (38.1 MB)
# Extracting...
# Found geopackage: bdc_36_130077_5GNR_35_3_mobile_broadband_h3_J25_03feb2026.gpkg
# Loaded 458950 rows, 9 columns
# Saved to ..\scraped_data\mno\att\1442799.csv
# Status: SUCCESS
#
# [2/6] Processing: 1442770
# --------------------------------------------------------------------------------
# Downloading file 1442770...
# Progress: 100.0% (8.7 MB)
# Downloaded (8.7 MB)
# Extracting...
# Found geopackage: bdc_34_130077_5GNR_35_3_mobile_broadband_h3_J25_03feb2026.gpkg
# Loaded 106481 rows, 9 columns
# Saved to ..\scraped_data\mno\att\1442770.csv
# Status: SUCCESS
#
# [3/6] Processing: 1442757
# --------------------------------------------------------------------------------
# Downloading file 1442757...
# Progress: 100.0% (44.2 MB)
# Downloaded (44.2 MB)
# Extracting...
# Found geopackage: bdc_42_130077_5GNR_35_3_mobile_broadband_h3_J25_03feb2026.gpkg
# Loaded 537862 rows, 9 columns
# Saved to ..\scraped_data\mno\att\1442757.csv
# Status: SUCCESS
#
# [4/6] Processing: 1442513
# --------------------------------------------------------------------------------
# Downloading file 1442513...
# Progress: 100.0% (53.4 MB)
# Downloaded (53.4 MB)
# Extracting...
# Found geopackage: bdc_42_130077_5GNR_7_1_mobile_broadband_h3_J25_03feb2026.gpkg
# Loaded 667395 rows, 9 columns
# Saved to ..\scraped_data\mno\att\1442513.csv
# Status: SUCCESS
#
# [5/6] Processing: 1442504
# --------------------------------------------------------------------------------
# Downloading file 1442504...
# Progress: 100.0% (12.1 MB)
# Downloaded (12.1 MB)
# Extracting...
# Found geopackage: bdc_34_130077_5GNR_7_1_mobile_broadband_h3_J25_03feb2026.gpkg
# Loaded 155273 rows, 9 columns
# Saved to ..\scraped_data\mno\att\1442504.csv
# Status: SUCCESS
#
# [6/6] Processing: 1442532
# --------------------------------------------------------------------------------
# Downloading file 1442532...
# Progress: 100.0% (52.9 MB)
# Downloaded (52.9 MB)
# Extracting...
# Found geopackage: bdc_36_130077_5GNR_7_1_mobile_broadband_h3_J25_03feb2026.gpkg
# Loaded 661293 rows, 9 columns
# Saved to ..\scraped_data\mno\att\1442532.csv
# Status: SUCCESS
#
# ================================================================================
# Complete — 6/6 succeeded
# Total rows saved: 2587254
# Results log: ..\scraped_data\mno\att\download_results.csv

# %%
import h3
import pandas as pd
import geopandas as gpd
from shapely.geometry import Polygon
from pathlib import Path

att_dir  = Path("../scraped_data/mno/att")
h3_dir   = Path("../scraped_data/mno/att/h3")
h3_dir.mkdir(parents=True, exist_ok=True)

# Load and combine all 6 data CSVs (skip the results log)
csvs = [f for f in att_dir.glob("*.csv") if f.name != "download_results.csv"]
df = pd.concat([pd.read_csv(f) for f in csvs], ignore_index=True)
print(f"Loaded {len(df):,} rows from {len(csvs)} files")
print(f"Technologies: {df['technology'].unique()}")

# Aggregate res9 — one row per hex, summarise across providers/technologies
def aggregate_h3(df, h3_col, target_res=None):
    if target_res is not None:
        df = df.copy()
        df[h3_col] = df[h3_col].apply(lambda h: h3.cell_to_parent(h, target_res))
    # attaches attributes
    return df.groupby(h3_col).agg(
        provider_count = (df.columns[df.columns.str.contains('provider|frn')][0], 'nunique'),
        tech_count     = ('technology', 'nunique'),
        avg_mindown    = ('mindown', 'mean'),
        avg_minup      = ('minup', 'mean'),
        avg_minsignal  = ('minsignal', 'mean'),
        hex_count      = (h3_col, 'count')
    ).reset_index()

# Build and export each resolution
resolutions = [
    # ("res9", None,  9),   # base data, no parent conversion
    ("res8", 8,     8),
    ("res7", 7,     7),
    ("res6", 6,     6),
    # ("res5", 5,     5),
]

for label, target_res, res_num in resolutions:
    print(f"\nAggregating {label}...")
    
    h3_col = "h3_res9_id"
    agg    = aggregate_h3(df, h3_col, target_res)
    agg    = agg.rename(columns={h3_col: "h3id"})
    
    # Convert H3 IDs to polygons
    gdf = gpd.GeoDataFrame(
        agg,
        geometry=[Polygon([(lng, lat) for lat, lng in h3.cell_to_boundary(hid)]) for hid in agg["h3id"]],
        crs="EPSG:4326"
    )
    
    out_path = h3_dir / f"att_{label}.geojson"
    gdf.to_file(out_path, driver="GeoJSON")
    print(f"  Saved {len(gdf):,} hexes → {out_path}")
# Out:
# Loaded 2,587,254 rows from 6 files
# Technologies: [500]
#
# Aggregating res8...
#   Saved 277,857 hexes → ..\scraped_data\mno\att\h3\att_res8.geojson
#
# Aggregating res7...
#   Saved 46,075 hexes → ..\scraped_data\mno\att\h3\att_res7.geojson
#
# Aggregating res6...
#   Saved 7,176 hexes → ..\scraped_data\mno\att\h3\att_res6.geojson

# %% [markdown]
# then run in the other notebook
